# %%
import warnings
import msmexplorer as msme
warnings.filterwarnings('ignore')
import seaborn as sns
# %pylab inline
import numpy as np
import os 
import pandas as pd
import mdtraj as md 
sns.set_style("whitegrid")
sns.set_context("talk",1.3)
from msmbuilder.utils import load,dump
# Out:
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The examples.directory rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2. In the future, examples will be found relative to the 'datapath' directory.
#   self[key] = other[key]
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
#   self[key] = other[key]
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.fileo rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/_collections_abc.py:841: MatplotlibDeprecationWarning:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
#   self[key] = other[key]
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/site-packages/seaborn/apionly.py:9: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)
# /Users/arghya/opt/anaconda3/envs/msmbuilder/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# Populating the interactive namespace from numpy and matplotlib

# %%
from msmbuilder.utils import verbosedump,verboseload

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199

# %%
# Nosincos transformation
df1=load('residues_nosincos.pkl')

# %% [markdown]
# ## Non sin/cos transformed features

# %%
df1
# Out:
#    resnames              atominds resseqs resids featurizer featuregroup  \
# 0     [SER]        [7, 9, 11, 14]    [39]   [38]   Dihedral         chi1
# 1     [ASN]      [28, 30, 32, 35]    [41]   [40]   Dihedral         chi1
# 2     [LEU]      [42, 44, 46, 49]    [42]   [41]   Dihedral         chi1
# 3     [TRP]      [61, 63, 65, 68]    [43]   [42]   Dihedral         chi1
# 4     [VAL]      [85, 87, 89, 91]    [44]   [43]   Dihedral         chi1
# 5     [PRO]  [101, 111, 108, 105]    [45]   [44]   Dihedral         chi1
# 6     [LYS]  [115, 117, 119, 122]    [74]   [73]   Dihedral         chi1
# 7     [VAL]  [137, 139, 141, 143]    [75]   [74]   Dihedral         chi1
# 8     [GLU]  [153, 155, 157, 160]    [76]   [75]   Dihedral         chi1
# 9     [MET]  [168, 170, 172, 175]    [77]   [76]   Dihedral         chi1
# 10    [ASN]  [185, 187, 189, 192]    [78]   [77]   Dihedral         chi1
# 11    [TYR]  [199, 201, 203, 206]    [79]   [78]   Dihedral         chi1
# 12    [VAL]  [220, 222, 224, 226]    [80]   [79]   Dihedral         chi1
# 13    [SER]  [236, 238, 240, 243]    [81]   [80]   Dihedral         chi1
# 14    [THR]  [254, 256, 258, 264]    [83]   [82]   Dihedral         chi1
# 15    [VAL]  [268, 270, 272, 274]    [84]   [83]   Dihedral         chi1
# 16    [SER]  [284, 286, 288, 291]    [85]   [84]   Dihedral         chi1
# 17    [PHE]  [302, 304, 306, 309]    [87]   [86]   Dihedral         chi1
# 18    [ASN]      [30, 32, 35, 36]    [41]   [40]   Dihedral         chi2
# 19    [LEU]      [44, 46, 49, 51]    [42]   [41]   Dihedral         chi2
# 20    [TRP]      [63, 65, 68, 69]    [43]   [42]   Dihedral         chi2
# 21    [PRO]  [111, 108, 105, 102]    [45]   [44]   Dihedral         chi2
# 22    [LYS]  [117, 119, 122, 125]    [74]   [73]   Dihedral         chi2
# 23    [GLU]  [155, 157, 160, 163]    [76]   [75]   Dihedral         chi2
# 24    [MET]  [170, 172, 175, 178]    [77]   [76]   Dihedral         chi2
# 25    [ASN]  [187, 189, 192, 193]    [78]   [77]   Dihedral         chi2
# 26    [TYR]  [201, 203, 206, 207]    [79]   [78]   Dihedral         chi2
# 27    [PHE]  [304, 306, 309, 310]    [87]   [86]   Dihedral         chi2
#
#    otherinfo
# 0   nosincos
# 1   nosincos
# 2   nosincos
# 3   nosincos
# 4   nosincos
# 5   nosincos
# 6   nosincos
# 7   nosincos
# 8   nosincos
# 9   nosincos
# 10  nosincos
# 11  nosincos
# 12  nosincos
# 13  nosincos
# 14  nosincos
# 15  nosincos
# 16  nosincos
# 17  nosincos
# 18  nosincos
# 19  nosincos
# 20  nosincos
# 21  nosincos
# 22  nosincos
# 23  nosincos
# 24  nosincos
# 25  nosincos
# 26  nosincos
# 27  nosincos

# %% [markdown]
# ## Transformed Features

# %%
import pandas as pd

# %%
#loading the feature
df=load('./residues.pkl')

# %%
#sincos transformed features
df
# Out:
#    resnames              atominds resseqs resids featurizer featuregroup  \
# 0     [SER]        [7, 9, 11, 14]    [39]   [38]   Dihedral         chi1
# 1     [ASN]      [28, 30, 32, 35]    [41]   [40]   Dihedral         chi1
# 2     [LEU]      [42, 44, 46, 49]    [42]   [41]   Dihedral         chi1
# 3     [TRP]      [61, 63, 65, 68]    [43]   [42]   Dihedral         chi1
# 4     [VAL]      [85, 87, 89, 91]    [44]   [43]   Dihedral         chi1
# 5     [PRO]  [101, 111, 108, 105]    [45]   [44]   Dihedral         chi1
# 6     [LYS]  [115, 117, 119, 122]    [74]   [73]   Dihedral         chi1
# 7     [VAL]  [137, 139, 141, 143]    [75]   [74]   Dihedral         chi1
# 8     [GLU]  [153, 155, 157, 160]    [76]   [75]   Dihedral         chi1
# 9     [MET]  [168, 170, 172, 175]    [77]   [76]   Dihedral         chi1
# 10    [ASN]  [185, 187, 189, 192]    [78]   [77]   Dihedral         chi1
# 11    [TYR]  [199, 201, 203, 206]    [79]   [78]   Dihedral         chi1
# 12    [VAL]  [220, 222, 224, 226]    [80]   [79]   Dihedral         chi1
# 13    [SER]  [236, 238, 240, 243]    [81]   [80]   Dihedral         chi1
# 14    [THR]  [254, 256, 258, 264]    [83]   [82]   Dihedral         chi1
# 15    [VAL]  [268, 270, 272, 274]    [84]   [83]   Dihedral         chi1
# 16    [SER]  [284, 286, 288, 291]    [85]   [84]   Dihedral         chi1
# 17    [PHE]  [302, 304, 306, 309]    [87]   [86]   Dihedral         chi1
# 18    [SER]        [7, 9, 11, 14]    [39]   [38]   Dihedral         chi1
# 19    [ASN]      [28, 30, 32, 35]    [41]   [40]   Dihedral         chi1
# 20    [LEU]      [42, 44, 46, 49]    [42]   [41]   Dihedral         chi1
# 21    [TRP]      [61, 63, 65, 68]    [43]   [42]   Dihedral         chi1
# 22    [VAL]      [85, 87, 89, 91]    [44]   [43]   Dihedral         chi1
# 23    [PRO]  [101, 111, 108, 105]    [45]   [44]   Dihedral         chi1
# 24    [LYS]  [115, 117, 119, 122]    [74]   [73]   Dihedral         chi1
# 25    [VAL]  [137, 139, 141, 143]    [75]   [74]   Dihedral         chi1
# 26    [GLU]  [153, 155, 157, 160]    [76]   [75]   Dihedral         chi1
# 27    [MET]  [168, 170, 172, 175]    [77]   [76]   Dihedral         chi1
# 28    [ASN]  [185, 187, 189, 192]    [78]   [77]   Dihedral         chi1
# 29    [TYR]  [199, 201, 203, 206]    [79]   [78]   Dihedral         chi1
# 30    [VAL]  [220, 222, 224, 226]    [80]   [79]   Dihedral         chi1
# 31    [SER]  [236, 238, 240, 243]    [81]   [80]   Dihedral         chi1
# 32    [THR]  [254, 256, 258, 264]    [83]   [82]   Dihedral         chi1
# 33    [VAL]  [268, 270, 272, 274]    [84]   [83]   Dihedral         chi1
# 34    [SER]  [284, 286, 288, 291]    [85]   [84]   Dihedral         chi1
# 35    [PHE]  [302, 304, 306, 309]    [87]   [86]   Dihedral         chi1
# 36    [ASN]      [30, 32, 35, 36]    [41]   [40]   Dihedral         chi2
# 37    [LEU]      [44, 46, 49, 51]    [42]   [41]   Dihedral         chi2
# 38    [TRP]      [63, 65, 68, 69]    [43]   [42]   Dihedral         chi2
# 39    [PRO]  [111, 108, 105, 102]    [45]   [44]   Dihedral         chi2
# 40    [LYS]  [117, 119, 122, 125]    [74]   [73]   Dihedral         chi2
# 41    [GLU]  [155, 157, 160, 163]    [76]   [75]   Dihedral         chi2
# 42    [MET]  [170, 172, 175, 178]    [77]   [76]   Dihedral         chi2
# 43    [ASN]  [187, 189, 192, 193]    [78]   [77]   Dihedral         chi2
# 44    [TYR]  [201, 203, 206, 207]    [79]   [78]   Dihedral         chi2
# 45    [PHE]  [304, 306, 309, 310]    [87]   [86]   Dihedral         chi2
# 46    [ASN]      [30, 32, 35, 36]    [41]   [40]   Dihedral         chi2
# 47    [LEU]      [44, 46, 49, 51]    [42]   [41]   Dihedral         chi2
# 48    [TRP]      [63, 65, 68, 69]    [43]   [42]   Dihedral         chi2
# 49    [PRO]  [111, 108, 105, 102]    [45]   [44]   Dihedral         chi2
# 50    [LYS]  [117, 119, 122, 125]    [74]   [73]   Dihedral         chi2
# 51    [GLU]  [155, 157, 160, 163]    [76]   [75]   Dihedral         chi2
# 52    [MET]  [170, 172, 175, 178]    [77]   [76]   Dihedral         chi2
# 53    [ASN]  [187, 189, 192, 193]    [78]   [77]   Dihedral         chi2
# 54    [TYR]  [201, 203, 206, 207]    [79]   [78]   Dihedral         chi2
# 55    [PHE]  [304, 306, 309, 310]    [87]   [86]   Dihedral         chi2
#
#    otherinfo
# 0        sin
# 1        sin
# 2        sin
# 3        sin
# 4        sin
# 5        sin
# 6        sin
# 7        sin
# 8        sin
# 9        sin
# 10       sin
# 11       sin
# 12       sin
# 13       sin
# 14       sin
# 15       sin
# 16       sin
# 17       sin
# 18       cos
# 19       cos
# 20       cos
# 21       cos
# 22       cos
# 23       cos
# 24       cos
# 25       cos
# 26       cos
# 27       cos
# 28       cos
# 29       cos
# 30       cos
# 31       cos
# 32       cos
# 33       cos
# 34       cos
# 35       cos
# 36       sin
# 37       sin
# 38       sin
# 39       sin
# 40       sin
# 41       sin
# 42       sin
# 43       sin
# 44       sin
# 45       sin
# 46       cos
# 47       cos
# 48       cos
# 49       cos
# 50       cos
# 51       cos
# 52       cos
# 53       cos
# 54       cos
# 55       cos
